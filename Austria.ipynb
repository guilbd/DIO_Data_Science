# %%
import pandas as pd

# %%
import matplotlib 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/drive/MyDrive/AUT.xlsx')

# %%
df.head()
# Out:
#    Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 0  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  2.50  2.96  3.20  2.33
# 1  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  5.00  1.77  3.51  4.33
# 2  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  8.09  1.45  4.09  7.09
# 3  Austria  Tipico Bundesliga  2012/2013 2012-07-22  ...  3.77  2.12  3.29  3.32
# 4  Austria  Tipico Bundesliga  2012/2013 2012-07-25  ...  2.10  3.53  3.28  2.00
#
# [5 rows x 19 columns]

# %%
df.tail()
# Out:
#       Country             League     Season  ...  AvgH   AvgD   AvgA
# 1660  Austria  Tipico Bundesliga  2020/2021  ...  2.85   3.73   2.25
# 1661  Austria  Tipico Bundesliga  2020/2021  ...  2.39   3.78   2.65
# 1662  Austria  Tipico Bundesliga  2020/2021  ...  1.11  10.37  17.16
# 1663  Austria  Tipico Bundesliga  2020/2021  ...  3.35   3.92   1.97
# 1664  Austria  Tipico Bundesliga  2020/2021  ...  2.75   3.52   2.42
#
# [5 rows x 19 columns]

# %%
df['Home'].unique()
# Out:
# array(['Sturm Graz', 'Mattersburg', 'Rapid Vienna', 'Admira',
#        'Wolfsberger AC', 'Austria Vienna', 'Neustadt', 'Salzburg',
#        'Wacker Innsbruck', 'Ried', 'Grodig', 'Altach', 'St. Polten',
#        'LASK', 'Hartberg', 'Tirol'], dtype=object)

# %%
df['home_id'] = df["Home"]

# %%
#df.insert(6, 'home_id', "Home")

# %%
# Alterando a posição de uma coluna
df.insert(6,'home_id', df.pop("home_id"))

# %%
df.head()
# Out:
#    Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 0  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  2.50  2.96  3.20  2.33
# 1  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  5.00  1.77  3.51  4.33
# 2  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  8.09  1.45  4.09  7.09
# 3  Austria  Tipico Bundesliga  2012/2013 2012-07-22  ...  3.77  2.12  3.29  3.32
# 4  Austria  Tipico Bundesliga  2012/2013 2012-07-25  ...  2.10  3.53  3.28  2.00
#
# [5 rows x 20 columns]

# %%
# Substituir valores de uma coluna
df['home_id'] = df['home_id'].map({'Sturm Graz': 1, 'Mattersburg': 2,
       'Rapid Vienna': 3, 'Admira':4, 'Wolfsberger AC': 5, 'Austria Vienna': 6, 
       'Neustadt': 7, 'Salzburg': 8, 'Wacker Innsbruck': 9, 'Ried': 10, 
       'Grodig': 11, 'Altach': 12, 'St. Polten': 13, 'LASK': 14, 'Hartberg': 15,
       'Tirol': 16}, na_action=None)

# %%
df.head()
# Out:
#    Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 0  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  2.50  2.96  3.20  2.33
# 1  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  5.00  1.77  3.51  4.33
# 2  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  8.09  1.45  4.09  7.09
# 3  Austria  Tipico Bundesliga  2012/2013 2012-07-22  ...  3.77  2.12  3.29  3.32
# 4  Austria  Tipico Bundesliga  2012/2013 2012-07-25  ...  2.10  3.53  3.28  2.00
#
# [5 rows x 20 columns]

# %%
# Criando uma nova coluna no DF. No caso dupliquei os dados da coluna AWAY
df['away_id'] = df["Away"]

# %%
df.head()
# Out:
#    Country             League     Season  ...  AvgD  AvgA           away_id
# 0  Austria  Tipico Bundesliga  2012/2013  ...  3.20  2.33          Salzburg
# 1  Austria  Tipico Bundesliga  2012/2013  ...  3.51  4.33          Neustadt
# 2  Austria  Tipico Bundesliga  2012/2013  ...  4.09  7.09  Wacker Innsbruck
# 3  Austria  Tipico Bundesliga  2012/2013  ...  3.29  3.32              Ried
# 4  Austria  Tipico Bundesliga  2012/2013  ...  3.28  2.00    Austria Vienna
#
# [5 rows x 21 columns]

# %%
# Alterando a posição de uma coluna
df.insert(8,'away_id', df.pop("away_id"))

# %%
df.head()
# Out:
#    Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 0  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  2.50  2.96  3.20  2.33
# 1  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  5.00  1.77  3.51  4.33
# 2  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  8.09  1.45  4.09  7.09
# 3  Austria  Tipico Bundesliga  2012/2013 2012-07-22  ...  3.77  2.12  3.29  3.32
# 4  Austria  Tipico Bundesliga  2012/2013 2012-07-25  ...  2.10  3.53  3.28  2.00
#
# [5 rows x 21 columns]

# %%
# Identificando os elementos únicos da coluna
df['Away'].unique()
# Out:
# array(['Salzburg', 'Neustadt', 'Wacker Innsbruck', 'Ried',
#        'Austria Vienna', 'Sturm Graz', 'Rapid Vienna', 'Mattersburg',
#        'Admira', 'Wolfsberger AC', 'Grodig', 'Altach', 'St. Polten',
#        'LASK', 'Hartberg', 'Tirol'], dtype=object)

# %%
# Criando INDEX para com seleção através de filtros utilizando MAP
df['away_id'] = df['away_id'].map({'Sturm Graz': 1, 'Mattersburg': 2,
       'Rapid Vienna': 3, 'Admira':4, 'Wolfsberger AC': 5, 'Austria Vienna': 6, 
       'Neustadt': 7, 'Salzburg': 8, 'Wacker Innsbruck': 9, 'Ried': 10, 
       'Grodig': 11, 'Altach': 12, 'St. Polten': 13, 'LASK': 14, 'Hartberg': 15,
       'Tirol': 16}, na_action=None)

# %%
df.head()
# Out:
#    Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 0  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  2.50  2.96  3.20  2.33
# 1  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  5.00  1.77  3.51  4.33
# 2  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  8.09  1.45  4.09  7.09
# 3  Austria  Tipico Bundesliga  2012/2013 2012-07-22  ...  3.77  2.12  3.29  3.32
# 4  Austria  Tipico Bundesliga  2012/2013 2012-07-25  ...  2.10  3.53  3.28  2.00
#
# [5 rows x 21 columns]

# %%
#Mostrando a quantidade de linhas com dados faltantes
df.isnull().sum()
# Out:
# Country    0
# League     0
# Season     0
# Date       0
# Time       0
# Home       0
# home_id    0
# Away       0
# away_id    0
# HG         0
# AG         0
# Res        0
# PH         3
# PD         3
# PA         3
# MaxH       0
# MaxD       0
# MaxA       0
# AvgH       0
# AvgD       0
# AvgA       0
# dtype: int64

# %%
# Apagando as linhas com os valores NULOS
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country    0
# League     0
# Season     0
# Date       0
# Time       0
# Home       0
# home_id    0
# Away       0
# away_id    0
# HG         0
# AG         0
# Res        0
# PH         0
# PD         0
# PA         0
# MaxH       0
# MaxD       0
# MaxA       0
# AvgH       0
# AvgD       0
# AvgA       0
# dtype: int64

# %%
df.dtypes
# Out:
# Country            object
# League             object
# Season             object
# Date       datetime64[ns]
# Time               object
# Home               object
# home_id             int64
# Away               object
# away_id             int64
# HG                  int64
# AG                  int64
# Res                 int64
# PH                float64
# PD                float64
# PA                float64
# MaxH              float64
# MaxD              float64
# MaxA              float64
# AvgH              float64
# AvgD              float64
# AvgA              float64
# dtype: object

# %%
df['HG'] = df['HG'].astype('int64')

# %%
df['AG'] = df['AG'].astype('int64')

# %%
df.dtypes
# Out:
# Country            object
# League             object
# Season             object
# Date       datetime64[ns]
# Time               object
# Home               object
# home_id             int64
# Away               object
# away_id             int64
# HG                  int64
# AG                  int64
# Res                 int64
# PH                float64
# PD                float64
# PA                float64
# MaxH              float64
# MaxD              float64
# MaxA              float64
# AvgH              float64
# AvgD              float64
# AvgA              float64
# dtype: object

# %%
df.head()
# Out:
#    Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 0  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  2.50  2.96  3.20  2.33
# 1  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  5.00  1.77  3.51  4.33
# 2  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  8.09  1.45  4.09  7.09
# 3  Austria  Tipico Bundesliga  2012/2013 2012-07-22  ...  3.77  2.12  3.29  3.32
# 4  Austria  Tipico Bundesliga  2012/2013 2012-07-25  ...  2.10  3.53  3.28  2.00
#
# [5 rows x 21 columns]

# %%
#Retornando o maior número de uma coluna
df['HG'].max()
# Out:
# 8

# %%
# Retornando o menor número de uma coluna
df['HG'].min()
# Out:
# 0

# %%
medians = df['HG'].median()

# %%
medians
# Out:
# 1.0

# %%
medians_AG = df['AG'].median()

# %%
medians_AG
# Out:
# 1.0

# %%
# Para identificar os jogos com mais gols df.nlargest(n, "nome_da_coluna")
df.nlargest(3, "HG")
# Out:
#      Country             League     Season       Date  ...  MaxA  AvgH   AvgD   AvgA
# 229  Austria  Tipico Bundesliga  2013/2014 2013-09-29  ...  19.0  1.12   9.14  15.34
# 378  Austria  Tipico Bundesliga  2014/2015 2014-08-10  ...  27.1  1.09  10.06  18.72
# 595  Austria  Tipico Bundesliga  2015/2016 2015-10-17  ...  19.0  1.18   7.21  12.70
#
# [3 rows x 21 columns]

# %%
df.nlargest(3, "AG")
# Out:
#       Country             League     Season       Date  ... MaxA   AvgH  AvgD  AvgA
# 695   Austria  Tipico Bundesliga  2015/2016 2016-04-23  ...  2.4   3.38  3.48  2.06
# 1520  Austria  Tipico Bundesliga  2020/2021 2020-11-28  ...  1.2  12.23  7.65  1.17
# 1608  Austria  Tipico Bundesliga  2020/2021 2021-04-04  ...  2.2   3.19  3.62  2.10
#
# [3 rows x 21 columns]

# %%
#nsmallest
df.nsmallest(3, "HG")
# Out:
#    Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 0  Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  2.50  2.96  3.20  2.33
# 3  Austria  Tipico Bundesliga  2012/2013 2012-07-22  ...  3.77  2.12  3.29  3.32
# 4  Austria  Tipico Bundesliga  2012/2013 2012-07-25  ...  2.10  3.53  3.28  2.00
#
# [3 rows x 21 columns]

# %%
df.nsmallest(3, "AG")
# Out:
#     Country             League     Season       Date  ...  MaxA  AvgH  AvgD  AvgA
# 1   Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  5.00  1.77  3.51  4.33
# 2   Austria  Tipico Bundesliga  2012/2013 2012-07-21  ...  8.09  1.45  4.09  7.09
# 13  Austria  Tipico Bundesliga  2012/2013 2012-08-05  ...  5.13  1.80  3.41  4.33
#
# [3 rows x 21 columns]

# %%
#Agrupamento por coluna - No exemplo total de gols por time quando joga em casa
df.groupby("Home")['HG'].sum()
# Out:
# Home
# Admira              201
# Altach              175
# Austria Vienna      281
# Grodig               86
# Hartberg             66
# LASK                122
# Mattersburg         132
# Neustadt             60
# Rapid Vienna        283
# Ried                159
# Salzburg            451
# St. Polten           88
# Sturm Graz          260
# Tirol                40
# Wacker Innsbruck     61
# Wolfsberger AC      227
# Name: HG, dtype: int64

# %%
#Agrupamento por coluna - No exemplo total de gols por time
df.groupby("Away")['AG'].sum()
# Out:
# Away
# Admira              167
# Altach              121
# Austria Vienna      241
# Grodig               70
# Hartberg             75
# LASK                108
# Mattersburg         113
# Neustadt             52
# Rapid Vienna        271
# Ried                108
# Salzburg            350
# St. Polten           94
# Sturm Graz          201
# Tirol                47
# Wacker Innsbruck     54
# Wolfsberger AC      192
# Name: AG, dtype: int64

# %%
#Ordenando o conjunto de dados - Os 10 maiores Gols Marcados em casa, do maior para o menor
df.sort_values("HG", ascending=False).head(10)
# Out:
#       Country             League     Season  ...  AvgH   AvgD   AvgA
# 378   Austria  Tipico Bundesliga  2014/2015  ...  1.09  10.06  18.72
# 595   Austria  Tipico Bundesliga  2015/2016  ...  1.18   7.21  12.70
# 229   Austria  Tipico Bundesliga  2013/2014  ...  1.12   9.14  15.34
# 1314  Austria  Tipico Bundesliga  2019/2020  ...  1.05  12.97  24.80
# 96    Austria  Tipico Bundesliga  2012/2013  ...  1.22   6.16  11.47
# 1273  Austria  Tipico Bundesliga  2018/2019  ...  1.08  10.22  23.93
# 192   Austria  Tipico Bundesliga  2013/2014  ...  2.07   3.35   3.42
# 1338  Austria  Tipico Bundesliga  2019/2020  ...  1.18   6.96  12.91
# 1493  Austria  Tipico Bundesliga  2020/2021  ...  1.05  13.57  27.06
# 1333  Austria  Tipico Bundesliga  2019/2020  ...  1.14   8.18  14.11
#
# [10 rows x 21 columns]

# %%
df.sort_values("AG", ascending=False).head(10)
# Out:
#       Country             League     Season       Date  ...  MaxA   AvgH  AvgD  AvgA
# 695   Austria  Tipico Bundesliga  2015/2016 2016-04-23  ...  2.40   3.38  3.48  2.06
# 1608  Austria  Tipico Bundesliga  2020/2021 2021-04-04  ...  2.20   3.19  3.62  2.10
# 1520  Austria  Tipico Bundesliga  2020/2021 2020-11-28  ...  1.20  12.23  7.65  1.17
# 1450  Austria  Tipico Bundesliga  2019/2020 2020-06-24  ...  1.50   6.72  5.10  1.38
# 1297  Austria  Tipico Bundesliga  2019/2020 2019-08-17  ...  1.17  15.62  7.83  1.14
# 617   Austria  Tipico Bundesliga  2015/2016 2015-11-21  ...  2.10   4.08  3.67  1.82
# 61    Austria  Tipico Bundesliga  2012/2013 2012-10-27  ...  2.49   2.95  3.31  2.31
# 829   Austria  Tipico Bundesliga  2016/2017 2017-02-19  ...  1.45   9.05  4.98  1.32
# 1418  Austria  Tipico Bundesliga  2019/2020 2020-06-07  ...  1.25  12.10  7.50  1.17
# 91    Austria  Tipico Bundesliga  2012/2013 2012-12-08  ...  1.85   4.62  3.58  1.73
#
# [10 rows x 21 columns]

# %% [markdown]
# ### **TRABALHANDO COM DATAS**

# %%
# Transformando a coluna de data em tipo inteiro
df["Date"] = df["Date"].astype('int64')

# %%
df.dtypes
# Out:
# Country     object
# League      object
# Season      object
# Date         int64
# Time        object
# Home        object
# home_id      int64
# Away        object
# away_id      int64
# HG           int64
# AG           int64
# Res          int64
# PH         float64
# PD         float64
# PA         float64
# MaxH       float64
# MaxD       float64
# MaxA       float64
# AvgH       float64
# AvgD       float64
# AvgA       float64
# dtype: object

# %%
# Transformando coluna de data em data
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Country            object
# League             object
# Season             object
# Date       datetime64[ns]
# Time               object
# Home               object
# home_id             int64
# Away               object
# away_id             int64
# HG                  int64
# AG                  int64
# Res                 int64
# PH                float64
# PD                float64
# PA                float64
# MaxH              float64
# MaxD              float64
# MaxA              float64
# AvgH              float64
# AvgD              float64
# AvgA              float64
# dtype: object

# %%
# Agrupamento por ano - Somando a quantidade de gols marcados em casa por ano
df.groupby(df["Date"].dt.year)["HG"].sum()
# Out:
# Date
# 2012    173
# 2013    331
# 2014    300
# 2015    308
# 2016    252
# 2017    278
# 2018    291
# 2019    329
# 2020    251
# 2021    179
# Name: HG, dtype: int64

# %%
df.groupby(df["Date"].dt.year)["AG"].sum()
# Out:
# Date
# 2012    134
# 2013    263
# 2014    227
# 2015    214
# 2016    219
# 2017    213
# 2018    255
# 2019    312
# 2020    255
# 2021    172
# Name: AG, dtype: int64

# %%
# Criando uma nova coluna com o ano

# %%
df["Ano do Jogo"] = df["Date"].dt.year

# %%
df.head()
# Out:
#    Country             League     Season  ...  AvgD  AvgA Ano do Jogo
# 0  Austria  Tipico Bundesliga  2012/2013  ...  3.20  2.33        2012
# 1  Austria  Tipico Bundesliga  2012/2013  ...  3.51  4.33        2012
# 2  Austria  Tipico Bundesliga  2012/2013  ...  4.09  7.09        2012
# 3  Austria  Tipico Bundesliga  2012/2013  ...  3.29  3.32        2012
# 4  Austria  Tipico Bundesliga  2012/2013  ...  3.28  2.00        2012
#
# [5 rows x 22 columns]

# %%
# Extraindo o mês e o dia
df["mes_jogo"], df["dia_jogo"] = (df["Date"]).dt.month, df["Date"].dt.day

# %%
df.head()
# Out:
#    Country             League     Season  ... Ano do Jogo mes_jogo dia_jogo
# 0  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       21
# 1  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       21
# 2  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       21
# 3  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       22
# 4  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       25
#
# [5 rows x 24 columns]

# %%
df.sample(20)
# Out:
#       Country             League     Season  ... Ano do Jogo mes_jogo dia_jogo
# 603   Austria  Tipico Bundesliga  2015/2016  ...        2015       10       24
# 1072  Austria  Tipico Bundesliga  2017/2018  ...        2018        5       20
# 823   Austria  Tipico Bundesliga  2016/2017  ...        2017        2       11
# 1650  Austria  Tipico Bundesliga  2020/2021  ...        2021        5       12
# 757   Austria  Tipico Bundesliga  2016/2017  ...        2016        9       17
# 357   Austria  Tipico Bundesliga  2013/2014  ...        2014        5       11
# 1161  Austria  Tipico Bundesliga  2018/2019  ...        2018       11       10
# 164   Austria  Tipico Bundesliga  2012/2013  ...        2013        5       12
# 1207  Austria  Tipico Bundesliga  2018/2019  ...        2019        3       10
# 506   Austria  Tipico Bundesliga  2014/2015  ...        2015        4       25
# 1088  Austria  Tipico Bundesliga  2018/2019  ...        2018        8        4
# ...

# %%
# Para apagar uma coluna
del df["Temporada/Ano"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temporada/Ano'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-1346b40776cc> in <module>()
# ...

# %%
df.head()
# Out:
#    Country             League     Season  ... Ano do Jogo mes_jogo dia_jogo
# 0  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       21
# 1  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       21
# 2  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       21
# 3  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       22
# 4  Austria  Tipico Bundesliga  2012/2013  ...        2012        7       25
#
# [5 rows x 24 columns]

# %%
# Retornando a data mais antiga
df["Date"].min()
# Out:
# Timestamp('2012-07-21 00:00:00')

# %%
# Calculando a diferença de dias
df["diferenca_dias"] = df["Date"] - df["Date"].min()

# %%
df.sample(5)
# Out:
#       Country             League     Season  ... mes_jogo dia_jogo diferenca_dias
# 1242  Austria  Tipico Bundesliga  2018/2019  ...        4       24      2468 days
# 1581  Austria  Tipico Bundesliga  2020/2021  ...        2       27      3143 days
# 1565  Austria  Tipico Bundesliga  2020/2021  ...        2       10      3126 days
# 1262  Austria  Tipico Bundesliga  2018/2019  ...        5       18      2492 days
# 1524  Austria  Tipico Bundesliga  2020/2021  ...       11       29      3053 days
#
# [5 rows x 25 columns]

# %%
# Criando a coluna trimestre
df["trimestre"] = df["Date"].dt.quarter

# %%
df.sample(5)
# Out:
#       Country             League     Season  ... dia_jogo diferenca_dias trimestre
# 935   Austria  Tipico Bundesliga  2017/2018  ...       16      1883 days         3
# 478   Austria  Tipico Bundesliga  2014/2015  ...       11       963 days         1
# 1408  Austria  Tipico Bundesliga  2019/2020  ...        8      2787 days         1
# 1096  Austria  Tipico Bundesliga  2018/2019  ...       11      2212 days         3
# 47    Austria  Tipico Bundesliga  2012/2013  ...       29        70 days         3
#
# [5 rows x 26 columns]

# %%
# Filtrando os jogos de mês/ano
jogos_12_2020 = df.loc[(df["Date"].dt.year == 2020) & (df["Date"].dt.month == 12) ]

# %%
jogos_12_2020
# Out:
#       Country             League     Season  ... dia_jogo diferenca_dias trimestre
# 1525  Austria  Tipico Bundesliga  2020/2021  ...        5      3059 days         4
# 1526  Austria  Tipico Bundesliga  2020/2021  ...        5      3059 days         4
# 1527  Austria  Tipico Bundesliga  2020/2021  ...        5      3059 days         4
# 1528  Austria  Tipico Bundesliga  2020/2021  ...        6      3060 days         4
# 1529  Austria  Tipico Bundesliga  2020/2021  ...        6      3060 days         4
# 1530  Austria  Tipico Bundesliga  2020/2021  ...        6      3060 days         4
# 1531  Austria  Tipico Bundesliga  2020/2021  ...       12      3066 days         4
# 1532  Austria  Tipico Bundesliga  2020/2021  ...       12      3066 days         4
# 1533  Austria  Tipico Bundesliga  2020/2021  ...       12      3066 days         4
# 1534  Austria  Tipico Bundesliga  2020/2021  ...       13      3067 days         4
# ...

# %% [markdown]
# ### **Visualização de Dados**

# %%
# Verifica quantas linhas tem com o valor
df["home_id"].value_counts(ascending=False)
# Out:
# 6     158
# 3     158
# 1     157
# 5     156
# 4     156
# 8     153
# 12    120
# 10    106
# 2     104
# 13     85
# 14     66
# 7      55
# 11     54
# 9      52
# 15     50
# 16     32
# Name: home_id, dtype: int64

# %%
# Biblioteca MATPLOTLIB para visualizar os gráficos
df["home_id"].value_counts(ascending=False).plot.bar()

# %%
df["home_id"].value_counts(ascending=True).plot.barh()

# %%
# O ';' serve para tirar a linha: <matplotlib.axes._subplots.AxesSubplot at 0x7f1a97508550>
df["home_id"].value_counts(ascending=True).plot.barh();

# %%
# Total de resultados
df["Res"].value_counts()
# Out:
# 1    722
# 2    552
# 0    388
# Name: Res, dtype: int64

# %%
# Adicionando um título e alterando o nome e cor dos eixos
df["Res"].value_counts().plot.bar(title="Total de jogos por resultado", color="green")
plt.xlabel("Resultado")
plt.ylabel("Total de Jogos")
# Out:
# Text(0, 0.5, 'Total de Jogos')

# %%
# Alterando o estilo
plt.style.use("ggplot")

# %%
df["Res"].value_counts().plot.pie(title="Total de jogos por resultado")
plt.xlabel("Resultado")
plt.ylabel("Total de Jogos")
plt.legend()

# %%
df.groupby(df["mes_jogo"])["home_id"].value_counts().plot()
plt.xlabel("Times da casa por ID")
plt.ylabel("Quantidade de Jogos")
# Out:
# Text(0, 0.5, 'Quantidade de Jogos')

# %%
 df_2020 = df[df["Ano do Jogo"] == 2020]

# %%
df_2020
# Out:
#       Country             League     Season  ... dia_jogo diferenca_dias trimestre
# 1385  Austria  Tipico Bundesliga  2019/2020  ...       14      2764 days         1
# 1386  Austria  Tipico Bundesliga  2019/2020  ...       15      2765 days         1
# 1387  Austria  Tipico Bundesliga  2019/2020  ...       15      2765 days         1
# 1388  Austria  Tipico Bundesliga  2019/2020  ...       16      2766 days         1
# 1389  Austria  Tipico Bundesliga  2019/2020  ...       16      2766 days         1
# ...       ...                ...        ...  ...      ...            ...       ...
# 1538  Austria  Tipico Bundesliga  2020/2021  ...       19      3073 days         4
# 1539  Austria  Tipico Bundesliga  2020/2021  ...       19      3073 days         4
# 1540  Austria  Tipico Bundesliga  2020/2021  ...       20      3074 days         4
# 1541  Austria  Tipico Bundesliga  2020/2021  ...       20      3074 days         4
# ...

# %%
df.groupby([df["Date"].dt.year, "Res"])["Home"].value_counts().sum()
# Out:
# 1662

# %%
#Histograma
plt.hist(df["home_id"], color="magenta");

# %%
# Salvando em PNG ==> savefig
df["Res"].value_counts().plot.bar(title="Total de jogos por resultado", color="green")
plt.xlabel("Resultado")
plt.ylabel("Total de Jogos")
plt.savefig('grafico PNG')

# %%
# Gráfico de Dispersão -  Times que mais jogaram
plt.scatter(x=df_2020["mes_jogo"], y = df_2020["home_id"]);
